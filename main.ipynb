# %%
import pandas as pd
import bar_chart_race as bcr

# %%
df = pd.read_excel('World_Minimum_Wages.xlsx')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                21 non-null     datetime64[ns]
#  1   Australia           21 non-null     float64
#  2   Belgium             21 non-null     float64
#  3   Canada              21 non-null     float64
#  4   Chile               21 non-null     float64
#  5   Colombia            21 non-null     float64
#  6   Costa Rica          21 non-null     float64
#  7   Czech Republic      21 non-null     float64
#  8   Estonia             21 non-null     float64
#  9   France              21 non-null     float64
#  10  Germany             21 non-null     float64
#  11  Greece              21 non-null     float64
#  12  Hungary             21 non-null     float64
#  13  Ireland             21 non-null     float64
#  14  Israel              21 non-null     float64
# ...

# %%
# Read CSV file and store in Dataframe
df = pd.read_excel("World_Minimum_Wages.xlsx", index_col=False)

df = df.set_index(['Date']).stack().T.reset_index()
df.rename(columns={ df.columns[1]: "Country" }, inplace = True)
df.rename(columns={ df.columns[2]: "Hourly Wage" }, inplace = True)
df.set_index('Date')
df.head(5)
# Out:
#         Date    Country  Hourly Wage
# 0 2001-01-01  Australia        10.97
# 1 2001-01-01    Belgium        11.48
# 2 2001-01-01     Canada         7.39
# 3 2001-01-01      Chile         2.06
# 4 2001-01-01   Colombia         2.08

# %%
df_unstack = df.set_index(['Country','Date']).unstack()['Hourly Wage'].T.reset_index()

df_unstack = df_unstack.set_index('Date') 

df_unstack.head()
# Out:
# Country     Australia  Belgium  Brazil  Bulgaria  Canada  Chile  Colombia
# Date
# 2001-01-01      10.97    11.48    1.16      1.00    7.39   2.06      2.08  \
# 2002-01-01      11.07    11.63    1.21      1.14    7.31   2.12      2.11
# 2003-01-01      11.22    11.57    1.25      1.22    7.21   2.15      2.12
# 2004-01-01      11.41    11.44    1.29      1.26    7.22   2.21      2.16
# 2005-01-01      11.51    11.35    1.36      1.49    7.29   2.25      2.19
#
# Country     Costa Rica  Croatia  Czech Republic  ...  Poland  Portugal
# Date                                             ...
# 2001-01-01        3.06     3.24            3.11  ...    3.43      4.75  \
# 2002-01-01        3.02     3.34            3.45  ...    3.37      4.77
# 2003-01-01        3.04     3.37            3.75  ...    3.52      4.74
# 2004-01-01        3.01     3.46            3.92  ...    3.51      4.74
# 2005-01-01        3.03     3.59            4.13  ...    3.54      4.75
#
# ...

# %%
import ffmpeg
import matplotlib
import matplotlib.animation as animation

# %%
import matplotlib.pyplot as plt
plt.rcParams['animation.ffmpeg_path'] = '/usr/local/bin/ffmpeg.exe' #on jupyter  don't forget the .exe

# %%
Writer1 = matplotlib.animation.PillowWriter(fps=30)
Writer2 = animation.FFMpegWriter(fps=30, codec='libx264')

# %%
Writer3 = matplotlib.animation.FFMpegWriter(fps=30)
# animation.save("animation.mp4", writer=Writer3)

# %%
bcr.bar_chart_race(df = df_unstack, 
                   sort='desc',
                   title='Title',
                   filename ='race.mp4',
                   writer=None)

# %%
pip install sjvisualizer-0.0.1-py3-none-any.whl
# Out:
# Processing ./sjvisualizer-0.0.1-py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.1/988.1 KB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 KB 4.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.4/735.4 KB 6.1 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/kevinkillion/VS Code Projects/World_Minimum_Wages/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sjvisualizer import DataHandler, Canvas, BarRace, StaticImage


EXCEL_FILE = "World_Minimum_Wages.xlsx"
FPS = 60
DURATION = 0.15

# load the data into a data frame
df = DataHandler.DataHandler(excel_file=EXCEL_FILE, number_of_frames=FPS*DURATION*60).df

# creating the canvas
canvas = Canvas.canvas()

# adding decoration with TkInter
line = canvas.canvas.create_line(800, 40, 800, 150, width=10, fill=Canvas._from_rgb((75, 75, 155)))

# adding the racing bar chart
bar_chart = BarRace.bar_race(df=df, canvas=canvas.canvas, width=2200, height=1000, x_pos=100)
canvas.add_sub_plot(bar_chart)

# adding a title
canvas.add_title("Nuclear Warheads by Country", color=(0,0,0))
canvas.add_sub_title("From 1950 - 2021", color=(150,150,150))

# adding a time
canvas.add_time(df=df, time_indicator="year")

# adding a logo
canvas.add_logo(logo="logo.png")

# adding a static image
ex = StaticImage.static_image(canvas=canvas.canvas, file="nuclear_explosion.png", x_pos = 650, y_pos=25, width=125, height=125)
canvas.add_sub_plot(ex)

# play the animation
canvas.play(fps=FPS)

# %%
from sjvisualizer import DataHandler, Canvas, BarRace, StaticImage

# %%
EXCEL_FILE = "World_Minimum_Wages.xlsx"
FPS = 60
DURATION = 0.15

# load the data into a data frame
df = DataHandler.DataHandler(excel_file=EXCEL_FILE, number_of_frames=FPS*DURATION*60).df
